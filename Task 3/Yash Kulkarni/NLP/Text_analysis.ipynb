# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\prask\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\prask\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\prask\AppData\Roaming\nltk_data...
# True

# %% [markdown]
# Tokenization - Breaking down a para into small chunks

# %%
from nltk.tokenize import sent_tokenize
text = """My name is Walter Hartwell White. I live at 308 Negra Arroyo Lane, Albuquerque, New Mexico, 87104. This is my confession. If you're watching this tape, I'm probably dead, murdered by my brother-in-law Hank Schrader. Hank has been building a meth empire for over a year now and using me as his chemist. Shortly after my 50th birthday, Hank came to me with a rather, shocking proposition. He asked that I use my chemistry knowledge to cook methamphetamine, which he would then sell using his connections in the drug world. Connections that he made through his career with the DEA. I was... astounded, I... I always thought that Hank was a very moral man and I was... thrown, confused, but I was also particularly vulnerable at the time, something he knew and took advantage of. I was reeling from a cancer diagnosis that was poised to bankrupt my family. Hank took me on a ride along, and showed me just how much money even a small meth operation could make. And I was weak. I didn't want my family to go into financial ruin so I agreed. Every day, I think back at that moment with regret. I quickly realized that I was in way over my head, and Hank had a partner, a man named Gustavo Fring, a businessman. Hank essentially sold me into servitude to this man, and when I tried to quit, Fring threatened my family. I didn't know where to turn. Eventually, Hank and Fring had a falling out. From what I can gather, Hank was always pushing for a greater share of the business, to which Fring flatly refused to give him, and things escalated. Fring was able to arrange, uh I guess I guess you call it a "hit" on my brother-in-law, and failed, but Hank was seriously injured, and I wound up paying his medical bills which amounted to a little over $177,000. Upon recovery, Hank was bent on revenge, working with a man named Hector Salamanca, he plotted to kill Fring, and did so. In fact, the bomb that he used was built by me, and he gave me no option in it. I have often contemplated suicide, but I'm a coward. I wanted to go to the police, but I was frightened. Hank had risen in the ranks to become the head of the Albuquerque DEA, and about that time, to keep me in line, he took my children from me. For 3 months he kept them. My wife, who up until that point, had no idea of my criminal activities, was horrified to learn what I had done, why Hank had taken our children. We were scared. I was in Hell, I hated myself for what I had brought upon my family. Recently, I tried once again to quit, to end this nightmare, and in response, he gave me this. I can't take this anymore. I live in fear every day that Hank will kill me, or worse, hurt my family. I... All I could think to do was to make this video in hope that the world will finally see this man, for what he really is."""
tokenized_sent = sent_tokenize(text)
print(tokenized_sent)
# Out:
# ['My name is Walter Hartwell White.', 'I live at 308 Negra Arroyo Lane, Albuquerque, New Mexico, 87104.', 'This is my confession.', "If you're watching this tape, I'm probably dead, murdered by my brother-in-law Hank Schrader.", 'Hank has been building a meth empire for over a year now and using me as his chemist.', 'Shortly after my 50th birthday, Hank came to me with a rather, shocking proposition.', 'He asked that I use my chemistry knowledge to cook methamphetamine, which he would then sell using his connections in the drug world.', 'Connections that he made through his career with the DEA.', 'I was... astounded, I...', 'I always thought that Hank was a very moral man and I was... thrown, confused, but I was also particularly vulnerable at the time, something he knew and took advantage of.', 'I was reeling from a cancer diagnosis that was poised to bankrupt my family.', 'Hank took me on a ride along, and showed me just how much money even a small meth operation could make.', 'And I was weak.', "I didn't want my family to go into financial ruin so I agreed.", 'Every day, I think back at that moment with regret.', 'I quickly realized that I was in way over my head, and Hank had a partner, a man named Gustavo Fring, a businessman.', 'Hank essentially sold me into servitude to this man, and when I tried to quit, Fring threatened my family.', "I didn't know where to turn.", 'Eventually, Hank and Fring had a falling out.', 'From what I can gather, Hank was always pushing for a greater share of the business, to which Fring flatly refused to give him, and things escalated.', 'Fring was able to arrange, uh I guess I guess you call it a "hit" on my brother-in-law, and failed, but Hank was seriously injured, and I wound up paying his medical bills which amounted to a little over $177,000.', 'Upon recovery, Hank was bent on revenge, working with a man named Hector Salamanca, he plotted to kill Fring, and did so.', 'In fact, the bomb that he used was built by me, and he gave me no option in it.', "I have often contemplated suicide, but I'm a coward.", 'I wanted to go to the police, but I was frightened.', 'Hank had risen in the ranks to become the head of the Albuquerque DEA, and about that time, to keep me in line, he took my children from me.', 'For 3 months he kept them.', 'My wife, who up until that point, had no idea of my criminal activities, was horrified to learn what I had done, why Hank had taken our children.', 'We were scared.', 'I was in Hell, I hated myself for what I had brought upon my family.', 'Recently, I tried once again to quit, to end this nightmare, and in response, he gave me this.', "I can't take this anymore.", 'I live in fear every day that Hank will kill me, or worse, hurt my family.', 'I... All I could think to do was to make this video in hope that the world will finally see this man, for what he really is.']

# %% [markdown]
# Word Tokenization - Breaks a paragraph into words

# %%
from nltk.tokenize import word_tokenize
tokenized_word = word_tokenize(text)
tokenized_word
# Out:
# ['My',
#  'name',
#  'is',
#  'Walter',
#  'Hartwell',
#  'White',
#  '.',
#  'I',
#  'live',
#  'at',
#  '308',
#  'Negra',
#  'Arroyo',
#  'Lane',
#  ',',
#  'Albuquerque',
#  ',',
#  'New',
#  'Mexico',
#  ',',
#  '87104',
#  '.',
#  'This',
#  'is',
#  'my',
#  'confession',
#  '.',
#  'If',
#  'you',
#  "'re",
#  'watching',
#  'this',
#  'tape',
#  ',',
#  'I',
#  "'m",
#  'probably',
#  'dead',
#  ',',
#  'murdered',
#  'by',
#  'my',
#  'brother-in-law',
#  'Hank',
#  'Schrader',
#  '.',
#  'Hank',
#  'has',
#  'been',
#  'building',
#  'a',
#  'meth',
#  'empire',
#  'for',
#  'over',
#  'a',
#  'year',
#  'now',
#  'and',
#  'using',
#  'me',
#  'as',
#  'his',
#  'chemist',
#  '.',
#  'Shortly',
#  'after',
#  'my',
#  '50th',
#  'birthday',
#  ',',
#  'Hank',
#  'came',
#  'to',
#  'me',
#  'with',
#  'a',
#  'rather',
#  ',',
#  'shocking',
#  'proposition',
#  '.',
#  'He',
#  'asked',
#  'that',
#  'I',
#  'use',
#  'my',
#  'chemistry',
#  'knowledge',
#  'to',
#  'cook',
#  'methamphetamine',
#  ',',
#  'which',
#  'he',
#  'would',
#  'then',
#  'sell',
#  'using',
#  'his',
#  'connections',
#  'in',
#  'the',
#  'drug',
#  'world',
#  '.',
#  'Connections',
#  'that',
#  'he',
#  'made',
#  'through',
#  'his',
#  'career',
#  'with',
#  'the',
#  'DEA',
#  '.',
#  'I',
#  'was',
#  '...',
#  'astounded',
#  ',',
#  'I',
#  '...',
#  'I',
#  'always',
#  'thought',
#  'that',
#  'Hank',
#  'was',
#  'a',
#  'very',
#  'moral',
#  'man',
#  'and',
#  'I',
#  'was',
#  '...',
#  'thrown',
#  ',',
#  'confused',
#  ',',
#  'but',
#  'I',
#  'was',
#  'also',
#  'particularly',
#  'vulnerable',
#  'at',
#  'the',
#  'time',
#  ',',
#  'something',
#  'he',
#  'knew',
#  'and',
#  'took',
#  'advantage',
#  'of',
#  '.',
#  'I',
#  'was',
#  'reeling',
#  'from',
#  'a',
#  'cancer',
#  'diagnosis',
#  'that',
#  'was',
#  'poised',
#  'to',
#  'bankrupt',
#  'my',
#  'family',
#  '.',
#  'Hank',
#  'took',
#  'me',
#  'on',
#  'a',
#  'ride',
#  'along',
#  ',',
#  'and',
#  'showed',
#  'me',
#  'just',
#  'how',
#  'much',
#  'money',
#  'even',
#  'a',
#  'small',
#  'meth',
#  'operation',
#  'could',
#  'make',
#  '.',
#  'And',
#  'I',
#  'was',
#  'weak',
#  '.',
#  'I',
#  'did',
#  "n't",
#  'want',
#  'my',
#  'family',
#  'to',
#  'go',
#  'into',
#  'financial',
#  'ruin',
#  'so',
#  'I',
#  'agreed',
#  '.',
#  'Every',
#  'day',
#  ',',
#  'I',
#  'think',
#  'back',
#  'at',
#  'that',
#  'moment',
#  'with',
#  'regret',
#  '.',
#  'I',
#  'quickly',
#  'realized',
#  'that',
#  'I',
#  'was',
#  'in',
#  'way',
#  'over',
#  'my',
#  'head',
#  ',',
#  'and',
#  'Hank',
#  'had',
#  'a',
#  'partner',
#  ',',
#  'a',
#  'man',
#  'named',
#  'Gustavo',
#  'Fring',
#  ',',
#  'a',
#  'businessman',
#  '.',
#  'Hank',
#  'essentially',
#  'sold',
#  'me',
#  'into',
#  'servitude',
#  'to',
#  'this',
#  'man',
#  ',',
#  'and',
#  'when',
#  'I',
#  'tried',
#  'to',
#  'quit',
#  ',',
#  'Fring',
#  'threatened',
#  'my',
#  'family',
#  '.',
#  'I',
#  'did',
#  "n't",
#  'know',
#  'where',
#  'to',
#  'turn',
#  '.',
#  'Eventually',
#  ',',
#  'Hank',
#  'and',
#  'Fring',
#  'had',
#  'a',
#  'falling',
#  'out',
#  '.',
#  'From',
#  'what',
#  'I',
#  'can',
#  'gather',
#  ',',
#  'Hank',
#  'was',
#  'always',
#  'pushing',
#  'for',
#  'a',
#  'greater',
#  'share',
#  'of',
#  'the',
#  'business',
#  ',',
#  'to',
#  'which',
#  'Fring',
#  'flatly',
#  'refused',
#  'to',
#  'give',
#  'him',
#  ',',
#  'and',
#  'things',
#  'escalated',
#  '.',
#  'Fring',
#  'was',
#  'able',
#  'to',
#  'arrange',
#  ',',
#  'uh',
#  'I',
#  'guess',
#  'I',
#  'guess',
#  'you',
#  'call',
#  'it',
#  'a',
#  '``',
#  'hit',
#  "''",
#  'on',
#  'my',
#  'brother-in-law',
#  ',',
#  'and',
#  'failed',
#  ',',
#  'but',
#  'Hank',
#  'was',
#  'seriously',
#  'injured',
#  ',',
#  'and',
#  'I',
#  'wound',
#  'up',
#  'paying',
#  'his',
#  'medical',
#  'bills',
#  'which',
#  'amounted',
#  'to',
#  'a',
#  'little',
#  'over',
#  '$',
#  '177,000',
#  '.',
#  'Upon',
#  'recovery',
#  ',',
#  'Hank',
#  'was',
#  'bent',
#  'on',
#  'revenge',
#  ',',
#  'working',
#  'with',
#  'a',
#  'man',
#  'named',
#  'Hector',
#  'Salamanca',
#  ',',
#  'he',
#  'plotted',
#  'to',
#  'kill',
#  'Fring',
#  ',',
#  'and',
#  'did',
#  'so',
#  '.',
#  'In',
#  'fact',
#  ',',
#  'the',
#  'bomb',
#  'that',
#  'he',
#  'used',
#  'was',
#  'built',
#  'by',
#  'me',
#  ',',
#  'and',
#  'he',
#  'gave',
#  'me',
#  'no',
#  'option',
#  'in',
#  'it',
#  '.',
#  'I',
#  'have',
#  'often',
#  'contemplated',
#  'suicide',
#  ',',
#  'but',
#  'I',
#  "'m",
#  'a',
#  'coward',
#  '.',
#  'I',
#  'wanted',
#  'to',
#  'go',
#  'to',
#  'the',
#  'police',
#  ',',
#  'but',
#  'I',
#  'was',
#  'frightened',
#  '.',
#  'Hank',
#  'had',
#  'risen',
#  'in',
#  'the',
#  'ranks',
#  'to',
#  'become',
#  'the',
#  'head',
#  'of',
#  'the',
#  'Albuquerque',
#  'DEA',
#  ',',
#  'and',
#  'about',
#  'that',
#  'time',
#  ',',
#  'to',
#  'keep',
#  'me',
#  'in',
#  'line',
#  ',',
#  'he',
#  'took',
#  'my',
#  'children',
#  'from',
#  'me',
#  '.',
#  'For',
#  '3',
#  'months',
#  'he',
#  'kept',
#  'them',
#  '.',
#  'My',
#  'wife',
#  ',',
#  'who',
#  'up',
#  'until',
#  'that',
#  'point',
#  ',',
#  'had',
#  'no',
#  'idea',
#  'of',
#  'my',
#  'criminal',
#  'activities',
#  ',',
#  'was',
#  'horrified',
#  'to',
#  'learn',
#  'what',
#  'I',
#  'had',
#  'done',
#  ',',
#  'why',
#  'Hank',
#  'had',
#  'taken',
#  'our',
#  'children',
#  '.',
#  'We',
#  'were',
#  'scared',
#  '.',
#  'I',
#  'was',
#  'in',
#  'Hell',
#  ',',
#  'I',
#  'hated',
#  'myself',
#  'for',
#  'what',
#  'I',
#  'had',
#  'brought',
#  'upon',
#  'my',
#  'family',
#  '.',
#  'Recently',
#  ',',
#  'I',
#  'tried',
#  'once',
#  'again',
#  'to',
#  'quit',
#  ',',
#  'to',
#  'end',
#  'this',
#  'nightmare',
#  ',',
#  'and',
#  'in',
#  'response',
#  ',',
#  'he',
#  'gave',
#  'me',
#  'this',
#  '.',
#  'I',
#  'ca',
#  "n't",
#  'take',
#  'this',
#  'anymore',
#  '.',
#  'I',
#  'live',
#  'in',
#  'fear',
#  'every',
#  'day',
#  'that',
#  'Hank',
#  'will',
#  'kill',
#  'me',
#  ',',
#  'or',
#  'worse',
#  ',',
#  'hurt',
#  'my',
#  'family',
#  '.',
#  'I',
#  '...',
#  'All',
#  'I',
#  'could',
#  'think',
#  'to',
#  'do',
#  'was',
#  'to',
#  'make',
#  'this',
#  'video',
#  'in',
#  'hope',
#  'that',
#  'the',
#  'world',
#  'will',
#  'finally',
#  'see',
#  'this',
#  'man',
#  ',',
#  'for',
#  'what',
#  'he',
#  'really',
#  'is',
#  '.']

# %% [markdown]
# Frequency Distribution

# %%
from nltk.probability import FreqDist
fdist = FreqDist(tokenized_word)
fdist
# Out:
# FreqDist({',': 50, 'I': 34, '.': 33, 'to': 21, 'was': 17, 'a': 16, 'Hank': 14, 'and': 14, 'my': 13, 'me': 11, ...})

# %%
fdist.most_common()
# Out:
# [(',', 50),
#  ('I', 34),
#  ('.', 33),
#  ('to', 21),
#  ('was', 17),
#  ('a', 16),
#  ('Hank', 14),
#  ('and', 14),
#  ('my', 13),
#  ('me', 11),
#  ('that', 11),
#  ('he', 10),
#  ('the', 10),
#  ('in', 9),
#  ('this', 7),
#  ('had', 7),
#  ('Fring', 6),
#  ('man', 5),
#  ('family', 5),
#  ('for', 4),
#  ('his', 4),
#  ('with', 4),
#  ('...', 4),
#  ('but', 4),
#  ('of', 4),
#  ('what', 4),
#  ('is', 3),
#  ('at', 3),
#  ('over', 3),
#  ('which', 3),
#  ('took', 3),
#  ('on', 3),
#  ('did', 3),
#  ("n't", 3),
#  ('My', 2),
#  ('live', 2),
#  ('Albuquerque', 2),
#  ('you', 2),
#  ("'m", 2),
#  ('by', 2),
#  ('brother-in-law', 2),
#  ('meth', 2),
#  ('using', 2),
#  ('world', 2),
#  ('DEA', 2),
#  ('always', 2),
#  ('time', 2),
#  ('from', 2),
#  ('could', 2),
#  ('make', 2),
#  ('go', 2),
#  ('into', 2),
#  ('so', 2),
#  ('day', 2),
#  ('think', 2),
#  ('head', 2),
#  ('named', 2),
#  ('tried', 2),
#  ('quit', 2),
#  ('guess', 2),
#  ('it', 2),
#  ('up', 2),
#  ('kill', 2),
#  ('gave', 2),
#  ('no', 2),
#  ('children', 2),
#  ('will', 2),
#  ('name', 1),
#  ('Walter', 1),
#  ('Hartwell', 1),
#  ('White', 1),
#  ('308', 1),
#  ('Negra', 1),
#  ('Arroyo', 1),
#  ('Lane', 1),
#  ('New', 1),
#  ('Mexico', 1),
#  ('87104', 1),
#  ('This', 1),
#  ('confession', 1),
#  ('If', 1),
#  ("'re", 1),
#  ('watching', 1),
#  ('tape', 1),
#  ('probably', 1),
#  ('dead', 1),
#  ('murdered', 1),
#  ('Schrader', 1),
#  ('has', 1),
#  ('been', 1),
#  ('building', 1),
#  ('empire', 1),
#  ('year', 1),
#  ('now', 1),
#  ('as', 1),
#  ('chemist', 1),
#  ('Shortly', 1),
#  ('after', 1),
#  ('50th', 1),
#  ('birthday', 1),
#  ('came', 1),
#  ('rather', 1),
#  ('shocking', 1),
#  ('proposition', 1),
#  ('He', 1),
#  ('asked', 1),
#  ('use', 1),
#  ('chemistry', 1),
#  ('knowledge', 1),
#  ('cook', 1),
#  ('methamphetamine', 1),
#  ('would', 1),
#  ('then', 1),
#  ('sell', 1),
#  ('connections', 1),
#  ('drug', 1),
#  ('Connections', 1),
#  ('made', 1),
#  ('through', 1),
#  ('career', 1),
#  ('astounded', 1),
#  ('thought', 1),
#  ('very', 1),
#  ('moral', 1),
#  ('thrown', 1),
#  ('confused', 1),
#  ('also', 1),
#  ('particularly', 1),
#  ('vulnerable', 1),
#  ('something', 1),
#  ('knew', 1),
#  ('advantage', 1),
#  ('reeling', 1),
#  ('cancer', 1),
#  ('diagnosis', 1),
#  ('poised', 1),
#  ('bankrupt', 1),
#  ('ride', 1),
#  ('along', 1),
#  ('showed', 1),
#  ('just', 1),
#  ('how', 1),
#  ('much', 1),
#  ('money', 1),
#  ('even', 1),
#  ('small', 1),
#  ('operation', 1),
#  ('And', 1),
#  ('weak', 1),
#  ('want', 1),
#  ('financial', 1),
#  ('ruin', 1),
#  ('agreed', 1),
#  ('Every', 1),
#  ('back', 1),
#  ('moment', 1),
#  ('regret', 1),
#  ('quickly', 1),
#  ('realized', 1),
#  ('way', 1),
#  ('partner', 1),
#  ('Gustavo', 1),
#  ('businessman', 1),
#  ('essentially', 1),
#  ('sold', 1),
#  ('servitude', 1),
#  ('when', 1),
#  ('threatened', 1),
#  ('know', 1),
#  ('where', 1),
#  ('turn', 1),
#  ('Eventually', 1),
#  ('falling', 1),
#  ('out', 1),
#  ('From', 1),
#  ('can', 1),
#  ('gather', 1),
#  ('pushing', 1),
#  ('greater', 1),
#  ('share', 1),
#  ('business', 1),
#  ('flatly', 1),
#  ('refused', 1),
#  ('give', 1),
#  ('him', 1),
#  ('things', 1),
#  ('escalated', 1),
#  ('able', 1),
#  ('arrange', 1),
#  ('uh', 1),
#  ('call', 1),
#  ('``', 1),
#  ('hit', 1),
#  ("''", 1),
#  ('failed', 1),
#  ('seriously', 1),
#  ('injured', 1),
#  ('wound', 1),
#  ('paying', 1),
#  ('medical', 1),
#  ('bills', 1),
#  ('amounted', 1),
#  ('little', 1),
#  ('$', 1),
#  ('177,000', 1),
#  ('Upon', 1),
#  ('recovery', 1),
#  ('bent', 1),
#  ('revenge', 1),
#  ('working', 1),
#  ('Hector', 1),
#  ('Salamanca', 1),
#  ('plotted', 1),
#  ('In', 1),
#  ('fact', 1),
#  ('bomb', 1),
#  ('used', 1),
#  ('built', 1),
#  ('option', 1),
#  ('have', 1),
#  ('often', 1),
#  ('contemplated', 1),
#  ('suicide', 1),
#  ('coward', 1),
#  ('wanted', 1),
#  ('police', 1),
#  ('frightened', 1),
#  ('risen', 1),
#  ('ranks', 1),
#  ('become', 1),
#  ('about', 1),
#  ('keep', 1),
#  ('line', 1),
#  ('For', 1),
#  ('3', 1),
#  ('months', 1),
#  ('kept', 1),
#  ('them', 1),
#  ('wife', 1),
#  ('who', 1),
#  ('until', 1),
#  ('point', 1),
#  ('idea', 1),
#  ('criminal', 1),
#  ('activities', 1),
#  ('horrified', 1),
#  ('learn', 1),
#  ('done', 1),
#  ('why', 1),
#  ('taken', 1),
#  ('our', 1),
#  ('We', 1),
#  ('were', 1),
#  ('scared', 1),
#  ('Hell', 1),
#  ('hated', 1),
#  ('myself', 1),
#  ('brought', 1),
#  ('upon', 1),
#  ('Recently', 1),
#  ('once', 1),
#  ('again', 1),
#  ('end', 1),
#  ('nightmare', 1),
#  ('response', 1),
#  ('ca', 1),
#  ('take', 1),
#  ('anymore', 1),
#  ('fear', 1),
#  ('every', 1),
#  ('or', 1),
#  ('worse', 1),
#  ('hurt', 1),
#  ('All', 1),
#  ('do', 1),
#  ('video', 1),
#  ('hope', 1),
#  ('finally', 1),
#  ('see', 1),
#  ('really', 1)]

# %% [markdown]
# Stopwords

# %%
from nltk.corpus import stopwords
stop_words = set(stopwords.words("english"))
(stop_words)
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
#Removing Stopwords
filteredSentence = []
for w in tokenized_word:
    if w not in stop_words:
        filteredSentence.append(w)
print("Tokeneized Sentence ", tokenized_sent)
print("Filtered Sentence ", filteredSentence)
# Out:
# Tokeneized Sentence  ['My name is Walter Hartwell White.', 'I live at 308 Negra Arroyo Lane, Albuquerque, New Mexico, 87104.', 'This is my confession.', "If you're watching this tape, I'm probably dead, murdered by my brother-in-law Hank Schrader.", 'Hank has been building a meth empire for over a year now and using me as his chemist.', 'Shortly after my 50th birthday, Hank came to me with a rather, shocking proposition.', 'He asked that I use my chemistry knowledge to cook methamphetamine, which he would then sell using his connections in the drug world.', 'Connections that he made through his career with the DEA.', 'I was... astounded, I...', 'I always thought that Hank was a very moral man and I was... thrown, confused, but I was also particularly vulnerable at the time, something he knew and took advantage of.', 'I was reeling from a cancer diagnosis that was poised to bankrupt my family.', 'Hank took me on a ride along, and showed me just how much money even a small meth operation could make.', 'And I was weak.', "I didn't want my family to go into financial ruin so I agreed.", 'Every day, I think back at that moment with regret.', 'I quickly realized that I was in way over my head, and Hank had a partner, a man named Gustavo Fring, a businessman.', 'Hank essentially sold me into servitude to this man, and when I tried to quit, Fring threatened my family.', "I didn't know where to turn.", 'Eventually, Hank and Fring had a falling out.', 'From what I can gather, Hank was always pushing for a greater share of the business, to which Fring flatly refused to give him, and things escalated.', 'Fring was able to arrange, uh I guess I guess you call it a "hit" on my brother-in-law, and failed, but Hank was seriously injured, and I wound up paying his medical bills which amounted to a little over $177,000.', 'Upon recovery, Hank was bent on revenge, working with a man named Hector Salamanca, he plotted to kill Fring, and did so.', 'In fact, the bomb that he used was built by me, and he gave me no option in it.', "I have often contemplated suicide, but I'm a coward.", 'I wanted to go to the police, but I was frightened.', 'Hank had risen in the ranks to become the head of the Albuquerque DEA, and about that time, to keep me in line, he took my children from me.', 'For 3 months he kept them.', 'My wife, who up until that point, had no idea of my criminal activities, was horrified to learn what I had done, why Hank had taken our children.', 'We were scared.', 'I was in Hell, I hated myself for what I had brought upon my family.', 'Recently, I tried once again to quit, to end this nightmare, and in response, he gave me this.', "I can't take this anymore.", 'I live in fear every day that Hank will kill me, or worse, hurt my family.', 'I... All I could think to do was to make this video in hope that the world will finally see this man, for what he really is.']
# Filtered Sentence  ['My', 'name', 'Walter', 'Hartwell', 'White', '.', 'I', 'live', '308', 'Negra', 'Arroyo', 'Lane', ',', 'Albuquerque', ',', 'New', 'Mexico', ',', '87104', '.', 'This', 'confession', '.', 'If', "'re", 'watching', 'tape', ',', 'I', "'m", 'probably', 'dead', ',', 'murdered', 'brother-in-law', 'Hank', 'Schrader', '.', 'Hank', 'building', 'meth', 'empire', 'year', 'using', 'chemist', '.', 'Shortly', '50th', 'birthday', ',', 'Hank', 'came', 'rather', ',', 'shocking', 'proposition', '.', 'He', 'asked', 'I', 'use', 'chemistry', 'knowledge', 'cook', 'methamphetamine', ',', 'would', 'sell', 'using', 'connections', 'drug', 'world', '.', 'Connections', 'made', 'career', 'DEA', '.', 'I', '...', 'astounded', ',', 'I', '...', 'I', 'always', 'thought', 'Hank', 'moral', 'man', 'I', '...', 'thrown', ',', 'confused', ',', 'I', 'also', 'particularly', 'vulnerable', 'time', ',', 'something', 'knew', 'took', 'advantage', '.', 'I', 'reeling', 'cancer', 'diagnosis', 'poised', 'bankrupt', 'family', '.', 'Hank', 'took', 'ride', 'along', ',', 'showed', 'much', 'money', 'even', 'small', 'meth', 'operation', 'could', 'make', '.', 'And', 'I', 'weak', '.', 'I', "n't", 'want', 'family', 'go', 'financial', 'ruin', 'I', 'agreed', '.', 'Every', 'day', ',', 'I', 'think', 'back', 'moment', 'regret', '.', 'I', 'quickly', 'realized', 'I', 'way', 'head', ',', 'Hank', 'partner', ',', 'man', 'named', 'Gustavo', 'Fring', ',', 'businessman', '.', 'Hank', 'essentially', 'sold', 'servitude', 'man', ',', 'I', 'tried', 'quit', ',', 'Fring', 'threatened', 'family', '.', 'I', "n't", 'know', 'turn', '.', 'Eventually', ',', 'Hank', 'Fring', 'falling', '.', 'From', 'I', 'gather', ',', 'Hank', 'always', 'pushing', 'greater', 'share', 'business', ',', 'Fring', 'flatly', 'refused', 'give', ',', 'things', 'escalated', '.', 'Fring', 'able', 'arrange', ',', 'uh', 'I', 'guess', 'I', 'guess', 'call', '``', 'hit', "''", 'brother-in-law', ',', 'failed', ',', 'Hank', 'seriously', 'injured', ',', 'I', 'wound', 'paying', 'medical', 'bills', 'amounted', 'little', '$', '177,000', '.', 'Upon', 'recovery', ',', 'Hank', 'bent', 'revenge', ',', 'working', 'man', 'named', 'Hector', 'Salamanca', ',', 'plotted', 'kill', 'Fring', ',', '.', 'In', 'fact', ',', 'bomb', 'used', 'built', ',', 'gave', 'option', '.', 'I', 'often', 'contemplated', 'suicide', ',', 'I', "'m", 'coward', '.', 'I', 'wanted', 'go', 'police', ',', 'I', 'frightened', '.', 'Hank', 'risen', 'ranks', 'become', 'head', 'Albuquerque', 'DEA', ',', 'time', ',', 'keep', 'line', ',', 'took', 'children', '.', 'For', '3', 'months', 'kept', '.', 'My', 'wife', ',', 'point', ',', 'idea', 'criminal', 'activities', ',', 'horrified', 'learn', 'I', 'done', ',', 'Hank', 'taken', 'children', '.', 'We', 'scared', '.', 'I', 'Hell', ',', 'I', 'hated', 'I', 'brought', 'upon', 'family', '.', 'Recently', ',', 'I', 'tried', 'quit', ',', 'end', 'nightmare', ',', 'response', ',', 'gave', '.', 'I', 'ca', "n't", 'take', 'anymore', '.', 'I', 'live', 'fear', 'every', 'day', 'Hank', 'kill', ',', 'worse', ',', 'hurt', 'family', '.', 'I', '...', 'All', 'I', 'could', 'think', 'make', 'video', 'hope', 'world', 'finally', 'see', 'man', ',', 'really', '.']

# %% [markdown]
# Stemming - Chops off a word

# %%
from nltk.stem import PorterStemmer

ps = PorterStemmer()

stemmed_words = []
for w in filteredSentence:
    stemmed_words.append(ps.stem(w))

print("Stemmed Sentence ", stemmed_words)
# Out:
# Stemmed Sentence  ['my', 'name', 'walter', 'hartwel', 'white', '.', 'i', 'live', '308', 'negra', 'arroyo', 'lane', ',', 'albuquerqu', ',', 'new', 'mexico', ',', '87104', '.', 'thi', 'confess', '.', 'if', "'re", 'watch', 'tape', ',', 'i', "'m", 'probabl', 'dead', ',', 'murder', 'brother-in-law', 'hank', 'schrader', '.', 'hank', 'build', 'meth', 'empir', 'year', 'use', 'chemist', '.', 'shortli', '50th', 'birthday', ',', 'hank', 'came', 'rather', ',', 'shock', 'proposit', '.', 'he', 'ask', 'i', 'use', 'chemistri', 'knowledg', 'cook', 'methamphetamin', ',', 'would', 'sell', 'use', 'connect', 'drug', 'world', '.', 'connect', 'made', 'career', 'dea', '.', 'i', '...', 'astound', ',', 'i', '...', 'i', 'alway', 'thought', 'hank', 'moral', 'man', 'i', '...', 'thrown', ',', 'confus', ',', 'i', 'also', 'particularli', 'vulner', 'time', ',', 'someth', 'knew', 'took', 'advantag', '.', 'i', 'reel', 'cancer', 'diagnosi', 'pois', 'bankrupt', 'famili', '.', 'hank', 'took', 'ride', 'along', ',', 'show', 'much', 'money', 'even', 'small', 'meth', 'oper', 'could', 'make', '.', 'and', 'i', 'weak', '.', 'i', "n't", 'want', 'famili', 'go', 'financi', 'ruin', 'i', 'agre', '.', 'everi', 'day', ',', 'i', 'think', 'back', 'moment', 'regret', '.', 'i', 'quickli', 'realiz', 'i', 'way', 'head', ',', 'hank', 'partner', ',', 'man', 'name', 'gustavo', 'fring', ',', 'businessman', '.', 'hank', 'essenti', 'sold', 'servitud', 'man', ',', 'i', 'tri', 'quit', ',', 'fring', 'threaten', 'famili', '.', 'i', "n't", 'know', 'turn', '.', 'eventu', ',', 'hank', 'fring', 'fall', '.', 'from', 'i', 'gather', ',', 'hank', 'alway', 'push', 'greater', 'share', 'busi', ',', 'fring', 'flatli', 'refus', 'give', ',', 'thing', 'escal', '.', 'fring', 'abl', 'arrang', ',', 'uh', 'i', 'guess', 'i', 'guess', 'call', '``', 'hit', "''", 'brother-in-law', ',', 'fail', ',', 'hank', 'serious', 'injur', ',', 'i', 'wound', 'pay', 'medic', 'bill', 'amount', 'littl', '$', '177,000', '.', 'upon', 'recoveri', ',', 'hank', 'bent', 'reveng', ',', 'work', 'man', 'name', 'hector', 'salamanca', ',', 'plot', 'kill', 'fring', ',', '.', 'in', 'fact', ',', 'bomb', 'use', 'built', ',', 'gave', 'option', '.', 'i', 'often', 'contempl', 'suicid', ',', 'i', "'m", 'coward', '.', 'i', 'want', 'go', 'polic', ',', 'i', 'frighten', '.', 'hank', 'risen', 'rank', 'becom', 'head', 'albuquerqu', 'dea', ',', 'time', ',', 'keep', 'line', ',', 'took', 'children', '.', 'for', '3', 'month', 'kept', '.', 'my', 'wife', ',', 'point', ',', 'idea', 'crimin', 'activ', ',', 'horrifi', 'learn', 'i', 'done', ',', 'hank', 'taken', 'children', '.', 'we', 'scare', '.', 'i', 'hell', ',', 'i', 'hate', 'i', 'brought', 'upon', 'famili', '.', 'recent', ',', 'i', 'tri', 'quit', ',', 'end', 'nightmar', ',', 'respons', ',', 'gave', '.', 'i', 'ca', "n't", 'take', 'anymor', '.', 'i', 'live', 'fear', 'everi', 'day', 'hank', 'kill', ',', 'wors', ',', 'hurt', 'famili', '.', 'i', '...', 'all', 'i', 'could', 'think', 'make', 'video', 'hope', 'world', 'final', 'see', 'man', ',', 'realli', '.']

# %% [markdown]
# Lemmitization - Derives root of a word

# %%
from nltk.stem.wordnet import WordNetLemmatizer
lem = WordNetLemmatizer()
stem = PorterStemmer()

word = "partying"
print("Lemmatized Word ", lem.lemmatize(word,"v"))
print("Stemmed Word ", stem.stem(word))
# Out:
# Lemmatized Word  party
# Stemmed Word  parti
